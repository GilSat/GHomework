# %% [markdown]
# #Homework 3
#
# This is an **investment calculator**. When you put in the amount invested, the expected rate, and how many years you intend to keep the investment, the program will return the return for every 5 years within the given year period.
#
# $Future Value = Principal*(1+rate)^{time}$

# %%
#Future Value Calc
principal = float(input("What is the future value?")) 


#find out what the rate is and do data validation to ensure it is a percent
rate = float(input("What rate do you expect to earn yearly?"))
if(rate > 1):
  rate /= 100

#find out how long this will be for 
time = int(input("How many years to you expect to hold this investment?"))

output = principal/(1+rate)**time
print(f"The present value of your investment is  ${output:,.2f}")

# %% [markdown]
# This is a **present value calculator**. You will input your intial invesment, the percentage rate it increases and the time you've had invested in it.

# %%
#Present Value Calc
principal = 100000
rate = .11
time = 30

output = principal/(1+rate)**time
print(f"The present value of your investment is  ${output:,.2f}")
